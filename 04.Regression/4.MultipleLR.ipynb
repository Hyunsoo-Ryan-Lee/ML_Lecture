# %% [markdown]
# ## 다중 선형 회귀 (Multiple Linear Regression)

# %% [markdown]
# ### 다중 선형 회귀 (Multiple Linear Regression)
#
# #### 개념
# - **정의**: 다중 선형 회귀는 여러 개의 독립 변수와 하나의 종속 변수 간의 관계를 모델링하는 회귀 분석 방법임.
# - **목적**: 여러 독립 변수를 사용하여 종속 변수의 값을 예측하고, 각 독립 변수가 종속 변수에 미치는 영향을 이해하고자 함.
#
# #### 수학적 표현식
# - **표현식**: $$y = \beta_0 + \beta_1x_1 + \beta_2x_2 + \cdots + \beta_nx_n + \epsilon $$
#
# #### 특징
# - **선형성**: 독립 변수와 종속 변수 간의 관계가 선형으로 가정됨.
# - **단순성**: 모델이 단순하고 해석이 용이함.
# - **다중 공선성**: 독립 변수들 간의 상관관계가 높을 경우 다중 공선성이 발생할 수 있으며, 이는 회귀 계수의 불안정성을 초래함.
#
# #### 사용 사례
# - **예측**: 여러 요소가 종속 변수에 영향을 미칠 때, 예를 들어, 광고비, 가격, 경쟁사 가격 등이 매출에 미치는 영향을 예측하고자 할 때 사용함.
# - **설명**: 각 독립 변수가 종속 변수에 미치는 영향을 파악하고자 할 때 유용함.
#
# ### 다항 선형 회귀 (Polynomial Linear Regression)
#
# #### 개념
# - **정의**: 다항 선형 회귀는 독립 변수와 종속 변수 간의 비선형 관계를 모델링하기 위해 독립 변수의 다항식을 사용하는 회귀 분석 방법임.
# - **목적**: 비선형 데이터에 대해 더 나은 예측을 제공하기 위해 독립 변수의 다항식을 추가함으로써 모델의 복잡성을 증가시킴.
#
# #### 수학적 표현식
# - **표현식**: $$ y = \beta_0 + \beta_1x + \beta_2x^2 + \beta_3x^3 + \cdots + \beta_nx^n + \epsilon $$
#   - 여기서 $$ y $$는 종속 변수, $$ x $$는 독립 변수, $$ x^2, x^3, \cdots, x^n $$은 독립 변수의 다항식 항, $$ \beta_0 $$는 절편, $$ \beta_1, \beta_2, \ldots, \beta_n $$은 각 항의 계수, $$ \epsilon $$은 오차항임.
#
# #### 특징
# - **비선형성**: 독립 변수와 종속 변수 간의 비선형 관계를 모델링할 수 있음.
# - **유연성**: 다항식의 차수를 높임으로써 더 복잡한 패턴을 학습할 수 있음.
# - **과적합**: 다항식의 차수가 너무 높으면 과적합이 발생할 수 있으며, 이는 모델의 일반화 성능을 저하시킬 수 있음.
#
# #### 사용 사례
# - **비선형 관계**: 독립 변수와 종속 변수 간에 비선형 관계가 명확한 경우 사용함. 예를 들어, 시간에 따른 주식 가격의 변동, 온도에 따른 압력 변화 등을 모델링할 때 유용함.
# - **패턴 탐지**: 데이터에서 더 복잡한 패턴을 감지하고자 할 때 사용함.
#
# ### 종합
# - **다중 선형 회귀**는 여러 독립 변수와 종속 변수 간의 **선형 관계**를 모델링함.
# - **다항 선형 회귀**는 독립 변수와 종속 변수 간의 **비선형 관계**를 모델링하기 위해 독립 변수의 다항식을 추가함.
# - 다중 선형 회귀는 **단순성**과 **해석 용이성**이 강점이며, 다항 선형 회귀는 **유연성**을 제공하지만 **과적합** 위험이 있음.
